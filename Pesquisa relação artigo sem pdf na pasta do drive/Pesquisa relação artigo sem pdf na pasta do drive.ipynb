# %% [markdown]
# <a href="https://colab.research.google.com/github/mlmarcosluan/bc/blob/main/Pesquisa%20rela%C3%A7%C3%A3o%20artigo%20sem%20pdf%20na%20pasta%20do%20drive/Pesquisa%20rela%C3%A7%C3%A3o%20artigo%20sem%20pdf%20na%20pasta%20do%20drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pesquisar quantos arquivos tem em uma pasta especifica

# %%
from google.colab import drive
import os

# montar drive
drive.mount('/content/drive')

# Link da pasta
pasta_drive = "/content/drive/Shareddrives/DTRI - BOLSISTAS/Analíticas/Base Dimensions/2022 - Rebeca Natalia/IA/IA_pdfs"



# Lista dos nomes dos arquivos
lista_nome = os.listdir(pasta_drive)

# Numeros de arquivos no pasta do drive
numero_arquivos = len(lista_nome)

# Devolvendo o numeros de nomes
print(f"O numero de arquivos é: {numero_arquivos}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# O numero de arquivos é: 35

# %% [markdown]
# # Salvar nomes dos arquivos em um txt, separados por ;

# %%
from google.colab import drive
import os

# montar drive
drive.mount('/content/drive')

# caminho das pastas
caminho_pasta = "/content/drive/Shareddrives/DTRI - BOLSISTAS/Analíticas/Base Dimensions/2022 - Rebeca Natalia/IFCH/IFCH_pdfs"
caminho_saida = "/content/drive/MyDrive/Bc/Scrips/nomes_arquivos.txt"

# Lista dos nomes dos arquivos
lista_nome = os.listdir(caminho_pasta)

# Salvar os nomes dos arquivos em um arquivo .txt separados por ";"
with open(caminho_saida, "w") as f:
    for file in lista_nome:
            f.write(file + "\n")  # Adiciona ";" e quebra de linha após cada nome
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Comparar listas de nomes de arquivos

# %%
from google.colab import drive
import os

# montar drive
drive.mount('/content/drive')

# caminho das pastas
# Drive  "/content/drive/Shareddrives/DTRI - BOLSISTAS/Analíticas/Base Dimensions/2022 - Rebeca Natalia/BAE_fazendo/BAE_pdfs"
# Saida lista de nomes no drive "/content/drive/MyDrive/Bc/Scrips/nomes.txt"
# Saida lista de relaçao de nomes sem arquivos "/content/drive/MyDrive/Bc/Scrips/nomes_sem_arquivos.txt"



# Função para colocar .pdf no final de cada nome dos arquivos
def aplica_pdf (lista_nome):
  for i in range(len(lista_nome)):
    lista_nome[i] = lista_nome[i] + ".pdf"

  return lista_nome

# Pega os dados da pasta dada
def puxa_dados(pasta_drive, arquivo_saida):
  # Lista dos nomes dos arquivos
  lista_nome = os.listdir(pasta_drive)

  # Salvar os nomes dos arquivos em um arquivo .txt separados por "\n"
  with open(arquivo_saida, "w") as f:
    for file in lista_nome:
            f.write(file + "\n")  # Adiciona ";" e quebra de linha após cada nome
  return lista_nome

# Pega dados de input de usuário
def pega_dados():
  lista_nome_excel = input("Cole os valores da coluna Nome do arquivo: ").split(" ")

  # Limpar lista
  while True:
    aux = 0
    for nome_excel in lista_nome_excel:

      # Verifica se o elemneto é vazio se for joga para o final da lista e apaga ele
      if nome_excel == "":
        elemento = lista_nome_excel.pop(aux)
        lista_nome_excel.append(elemento)
        del lista_nome_excel[-1]
        break
      else: # Nome copia e cola excel não é vazio
        aux += 1
    if aux == len(lista_nome_excel):
      break

  lista_nome_excel = aplica_pdf(lista_nome_excel)

  return lista_nome_excel

def montegem_caminho():
  montagem_caminho = input("Digite o caminho da pasta/arquivo: ")
  return montagem_caminho

def limpa_lista(arquivo_saida):
  with open(arquivo_saida, "w") as f:
    f.write("")



def pesquisa_nomes(pasta_drive, arquivo_saida_nomes, arquivo_saida_relacao, copia_cola_excel):
  # Primeiro limpamos os arquivos de saidas
  limpa_lista(arquivo_saida_nomes)
  limpa_lista(arquivo_saida_relacao)

  # Segundo pegamos os dados do drive
  lista_nome_drive = puxa_dados(pasta_drive, arquivo_saida_nomes)
  # Quarto rodamos um script de busca nome por nome

  # pega o primeiro nome da lista de nomes do copia e cola do excel e verifica com todos os nomes do drive
  # passa para o segundo nome, depois para o terceiro e assim até passar por todos os nomes do copia e cola do excel
  for nome_excel in copia_cola_excel:
    verificacao = True
    for nome_drive in lista_nome_drive:
      if nome_excel == nome_drive:
        verificacao = True
        break

      else:
        verificacao = False
    if verificacao == False:
      nome_excel_sem_pdf = nome_excel.replace(".pdf", "")
      with open(arquivo_saida_relacao, "a") as f:
        f.write(nome_excel_sem_pdf + "\n")

  print("####################################")
  print("#                                  #")
  print("#                                  #")
  print("#       Pesquisa concluida.        #")
  print("#                                  #")
  print("#                                  #")
  print("####################################")
  print("")
  print("")
  print("")
  print("Arquivo salvo em: ", arquivo_saida_relacao)




def menu():
  estado = 2

  pasta_drive = "/content/drive/Shareddrives/DTRI - BOLSISTAS/Analíticas/Base Dimensions/2022 - Rebeca Natalia/BAE_fazendo/BAE_pdfs"
  arquivo_saida_nomes = "/content/drive/MyDrive/Bc/Scrips/nomes.txt"
  arquivo_saida_relacao = "/content/drive/MyDrive/Bc/Scrips/nomes_sem_arquivos.txt"
  copia_cola_excel = ""
  """
  pasta_drive = ""
  arquivo_saida_nomes = ""
  arquivo_saida_relacao = ""
  copia_cola_excel = ""
  """
  while estado != 0:
    print("####################################")
    print("")
    print("")
    print("1, Adicionar pasta para pesquisa.")
    print("2, Acicionar arquivo de saida da lista de nomes.")
    print("3, Adicionar arquivo de saida da relação de nomes sem arquivos.")
    print("4, Adicionar nomes do copia e cola do excel.")
    print("0, sair.")
    print("")
    print("Pasta do drive para pesquisa: ", pasta_drive)
    print("Arquivo para salvar nomes.txt", arquivo_saida_nomes)
    print("Arquivo para salvar relação de nomes sem arquivos", arquivo_saida_relacao)
    if copia_cola_excel != "":
      print("Lista de nomes do excel copiado.")
    else:
      print("Lista de nomes do excel não copiado.")
    print("")
    print("")
    print("")
    print("")
    print("5, Pesquisar")
    estado = int(input("Opção escolhida: "))

    if estado == 1:
      print("####################################")
      print("")
      print("")
      pasta_drive = montegem_caminho()

    elif estado == 2:
      print("####################################")
      print("")
      print("")
      arquivo_saida_nomes = montegem_caminho()

    elif estado == 3:
      print("####################################")
      print("")
      print("")
      arquivo_saida_relacao = montegem_caminho()

    elif estado == 4:
      print("####################################")
      print("")
      print("")
      copia_cola_excel = pega_dados()

    elif estado == 5:
      if pasta_drive != "" and arquivo_saida_nomes != "" and arquivo_saida_relacao != "" and copia_cola_excel != "":
        pesquisa_nomes(pasta_drive, arquivo_saida_nomes, arquivo_saida_relacao, copia_cola_excel)
      else:
        print("####################################")
        print("#                                  #")
        print("#    Preencha todos os campos.     #")
        print("#                                  #")
        print("####################################")
        print("")
        print("")
        print("")

    elif estado == 6:
        print("################################")
        print("#     #")
        print("################################")
        print("")
        print("")
        print("")

    elif estado == 0:
      break
    else:
      print("Opção invalida.")

# Função principal
def main ():

  # Fica em loop até a opção for 0
  estado = 2
  while estado != 0:
    # Imprime duas opções, 0 sair ou 1 continuar
    print("####################################")
    print("")
    print("")
    print("0, sair.")
    print("1, continuar.")
    estado = int(input("Digite: "))
    if estado == 1:
      menu()
    elif estado == 0:
      break
    else:
      print("Opção invalida.")

main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 0, sair.
# 1, continuar.
# Digite: 1
# ####################################
#
#
# 1, Adicionar pasta para pesquisa.
# 2, Acicionar arquivo de saida da lista de nomes.
# 3, Adicionar arquivo de saida da relação de nomes sem arquivos.
# 4, Adicionar nomes do copia e cola do excel.
# 0, sair.
#
# Pasta do drive para pesquisa:  /content/drive/Shareddrives/DTRI - BOLSISTAS/Analíticas/Base Dimensions/2022 - Rebeca Natalia/BAE_fazendo/BAE_pdfs
# Arquivo para salvar nomes.txt /content/drive/MyDrive/Bc/Scrips/nomes.txt
# Arquivo para salvar relação de nomes sem arquivos /content/drive/MyDrive/Bc/Scrips/nomes_sem_arquivos.txt
# Lista de nomes do excel não copiado.
#
#
#
#
# 5, Pesquisar
# Opção escolhida: 4
# ####################################
#
#
# Cole os valores da coluna Nome do arquivo: 101038s41598022268432 1010881742659624071012045 101016jest2022105770 101016jiot2022100624 101007978303101241917 101016jjmrt202208066 101016joptlastec2022108196 101109sbmicro5582220229881025 101007s44174022000214 101021acsanm2c02402 101016jmicrorel2022114592 101016jest2022104793 101038s41598022161676 101109igarss4683420229884086 101109igarss4683420229883865 101109apsusncursi4703220229886821 101016jcolsurfb2022112693 101016jalgal2022102796 101016jjechem202202055 101002cae22543 101016jmtcomm2022103726 101016jest2022104219 101002ceat202100589 101007s1047002202041y 101016jjmrt202203136 103390s22093256 1010079783030706012346 103390rs14071734 101016jrser2022112078 101016jces2021117274 101016jjechem202111010 103390nano12040676  101016jcolsurfb2022112359 101016jjcou2021101865 101016jjfoodeng2021110812 101007s11998021005603 101039d1ma00890k 101109jsen20223168228 101016jelectacta2021139299 10159018094430engagricv42n5e202102392022 101016b978032390477300002x 1020396laborev16i008671867 1020396laborev16i008671644  101007978303121686237 101016jengappai2022105462 101016jeswa2022117898  105753svrestendido2022227649 101109jstars20223209101 101016jbdr2022100333 101109ijcnn5506420229892809 101016jcie2022108171 101016jasoc2022108727 1021203rs3rs1466902v1 1022409geographia2022v24i52a50112 103390polysaccharides3010014 101016jeswa2021115874 101109twc20223231496 101109gcwkshps56602202210008540 103390biomass2040024 101109latincom56090202210000542 101016jclce2022100074 101016jindcrop2022115788 101016jjlp2022104892 101016jdche2022100059 101016jcma2022115476 101016jcma2022115408 101007s0015802203448x 105753kdmile2022227807 105753eniac2022227592 101016jjbiotec202211007 101109wfiot54382202210152029 101002cjce24653 101016jspc202209009 101016jpetrol2022111005 101016jjobe2022105184 101016jegyr202207154 101007s1215502210532z  101016jbiombioe2022106582 101016jcej2022137159 101109tap20223209206 103390math10193467 101002nme7103 101038s41597022016382 101016jpetrol2022110830 101016jpetrol2022110814 101016jpetrol2022110766 101016jfuel2022124702 103390aerospace9090470 101007s40430022037136 Erro ao abrir a página 1011111365247813249  101016jceja2022100336 101016jpetrol2022110707 101016jtsep2022101347 101016jcattod202108013 1055037lxlaser20th48  103389fnins2022919186 10117714680874221106976 101016jpowtec2022117597 101016jenconman2022115689 101016jjclepro2022132051 101016jpetrol2022110482 101016jindcrop2022114808 101109lcsys20223185976     1021203rs3rs1692600v1 101016jjiec202203028  101109icassp4392220229746043 101002nag3378 101038s41598022124526 1010801744530220222075647 1010800305215x20222065481 10114919457111ac70fd 101016jsupflu2022105567 101016jpetrol2022110329 101016jceja2022100271 101016jpetrol2022110291 101016jpetrol2022110267 101016jtriboint2022107469 101021acsaem1c03750 101002cptc202200007   101007s13399022026338 101061ascebe194355920001873 10111514054135 103390bioengineering9040164 10100797830309345695 101016jijmultiphaseflow2022103972 101016jpetrol2021110071 101016jrser2021112039 101016jfinel2021103701 10100797830309186992 101109tte20223162405 10110120220321484299 101007s4094802200344y 10114919457111ac59f6 101016jcompchemeng2022107670 101016jpetrol2021110089 101016jpetrol2021110083 101016jpetrol2021109937 101016jpetrol2021109970 101007s10596022101297 10111514053435 101016jpetrol2021109851 101016jces2021117198 101016jexpthermflusci2021110521 101016jymssp2021108356 101109memc202210058836 101109access20223214229 101109lgrs20223187554 101109access20223175487 101109lgrs20223152936 101016jjvcir2021103395 101016japt202110.032 101016jpetrol2021109708 101016jpetrol2021109571 101016jpetrol2021109570 101016jces2021117050 101016jpetrol2021109260 10399722144609202287018 1015900104142820220009 10399722144609202244095 10399722144609202244015 101590167978257062 101016b9780323958790502186 101016b9780323958790500539 101016b9780323958790500618 101016b9780323851596503067 101016b9780323851596501846 101590s198341952022000500005 101590s19834 ...
# ####################################
#
#
# 1, Adicionar pasta para pesquisa.
# 2, Acicionar arquivo de saida da lista de nomes.
# 3, Adicionar arquivo de saida da relação de nomes sem arquivos.
# 4, Adicionar nomes do copia e cola do excel.
# 0, sair.
#
# Pasta do drive para pesquisa:  /content/drive/Shareddrives/DTRI - BOLSISTAS/Analíticas/Base Dimensions/2022 - Rebeca Natalia/BAE_fazendo/BAE_pdfs
# Arquivo para salvar nomes.txt /content/drive/MyDrive/Bc/Scrips/nomes.txt
# Arquivo para salvar relação de nomes sem arquivos /content/drive/MyDrive/Bc/Scrips/nomes_sem_arquivos.txt
# Lista de nomes do excel copiado.
#
#
#
#
# 5, Pesquisar
# Opção escolhida: 5
# ####################################
# #                                  #
# #                                  #
# #       Pesquisa concluida.        #
# #                                  #
# #                                  #
# ####################################
#
#
#
# Arquivo salvo em:  /content/drive/MyDrive/Bc/Scrips/nomes_sem_arquivos.txt
# ####################################
#
#
# 1, Adicionar pasta para pesquisa.
# 2, Acicionar arquivo de saida da lista de nomes.
# 3, Adicionar arquivo de saida da relação de nomes sem arquivos.
# 4, Adicionar nomes do copia e cola do excel.
# 0, sair.
#
# Pasta do drive para pesquisa:  /content/drive/Shareddrives/DTRI - BOLSISTAS/Analíticas/Base Dimensions/2022 - Rebeca Natalia/BAE_fazendo/BAE_pdfs
# Arquivo para salvar nomes.txt /content/drive/MyDrive/Bc/Scrips/nomes.txt
# Arquivo para salvar relação de nomes sem arquivos /content/drive/MyDrive/Bc/Scrips/nomes_sem_arquivos.txt
# Lista de nomes do excel copiado.
#
#
#
#
# 5, Pesquisar
# Opção escolhida: 0
# 0, sair.
# 1, continuar.
# Digite: 0
